# %% [markdown]
# ### Find scientific descriptions of TERRA-REF Seasons
#
# TERRA-REF maintains a public API that records experiments, treatments, events, etc.  Explore this API to uncover descriptions for the scientific reasons behind the designs of the experiments.

# %%
import requests
import pandas as pd

# %%
r = requests.get('https://terraref.ncsa.illinois.edu/bety/api/v1/experiments')

# %%
r.json().keys()
# Out:
# dict_keys(['metadata', 'data'])

# %%
# what does the record for a single experiment look like? 
r.json()['data'][0]
# Out:
# {'experiment': {'id': 6000000012,
#   'name': 'Danforth Sorghum Pilot: Drought Tolerance',
#   'start_date': '2014-05-27',
#   'end_date': '2014-06-24',
#   'description': '# Materials\r\n\r\nProMix BRK20 + 14-14-14 Osmocote pots; pre-filled by Hummert Sorghum seed\r\nConviron Growth House\r\nLemnaTec moving field conveyor belt system\r\nScanalyzer 3D platform\r\n\r\n# Procedures\r\n\r\n## Planting\r\n\r\nPlant directly into phenotyping pots \r\n\r\n## Chamber Conditions\r\n\r\nPre-growth (11 days) and Phenotying (11 days)\r\n14 hour photoperiod\r\n32 C day / 22 C night temperature\r\n60% relative humidity\r\n700 umol/m2/s light\r\n\r\nWatering Conditions\r\nPrior to phenotyping, plants watered daily\r\nThe first night after loading, plants watered 1× by treatment group to 100% field capacity (fc)\r\nDays 2 – 12, plants watered 2× daily by treatment group (100% or 30% FC) to target weight\r\nAutomation\r\n\r\nLeft shift lane rotation within each GH, during overnight watering jobs\r\nVIS (TV and 2 x SV), NIR (TV and 2 x SV) imaging daily\r\nRecipes\r\n\r\nField capacity = 200% GWC (200 g water/100 g soil), based upon extensive GWC testing done by Skyler Mitchell\r\nTarget weight (fc) = [(water weight at % fc) + [(average weight of carrier/saucer) + (dry soil weight) + (pot weight)]\r\nWater weight at 100% fc = dry soil weight * (%GWC/100)\r\nWater weight at 30% fc = water weight at 100% fc * 0.30',
#   'design': '',
#   'user_id': 6000000004,
#   'created_at': '2017-06-07 15:44:28 -0500',
#   'updated_at': '2017-12-04 18:16:46 -0600',
#   'number of associated experiments_sites': 1,
#   'number of associated sites': 1,
#   'view_url': 'https://terraref.ncsa.illinois.edu/bety/experiments/6000000012',
#   'edit_url': 'https://terraref.ncsa.illinois.edu/bety/experiments/6000000012/edit'}}

# %%
# explore the fields in each experiment
r.json()['data'][0]['experiment'].keys()
# Out:
# dict_keys(['id', 'name', 'start_date', 'end_date', 'description', 'design', 'user_id', 'created_at', 'updated_at', 'number of associated experiments_sites', 'number of associated sites', 'view_url', 'edit_url'])

# %%
# build a dataframe of the experiments and their descriptive attributes. 
experiment_list = []
for exp in r.json()['data']:
    #print(exp)
    experiment_list.append(exp['experiment'])
experiment_df = pd.DataFrame(experiment_list)
experiment_df.head()
# Out:
#            id                                               name  start_date  \
# 0  6000000012          Danforth Sorghum Pilot: Drought Tolerance  2014-05-27
# 1  6000000009              KSU 2016-1: Biomass Association Panel  2016-03-15
# 2  6000000013              KSU 2016-2: Ashland Bottoms BAP & RIL  2016-06-07
# 3  6000000033                         MAC Season 5: Winter Wheat  2017-11-20
# 4  6000000031  Danforth BAP Drought LT1b: Drought Experiment ...  2016-05-16
#
#      end_date                                        description  \
# 0  2014-06-24  # Materials\r\n\r\nProMix BRK20 + 14-14-14 Osm...
# 1  2016-10-25  Bioenergy association panel (BAP) study at KSU...
# 2  2016-10-21  Germplasm used for the project\r\n1) Bioenergy...
# 3  2018-04-05  Durum wheat diversity panel (UNIBO panel) plan...
# 4  2016-06-07  Sorghum Bioenergy Association Panel drought ex...
#
#                                               design     user_id  \
# 0                                                     6000000004
# 1  Field location Ashland Bottoms\r\nRandomized B...  6000000004
# 2  Randomized Block Design with augmentation, 2 e...  6000000004
# 3         Resolvable row-column design, 2 replicates  6000000004
# 4  Planting was done on 2016-05-16. Germination a...  6000000008
#
#                   created_at                 updated_at  \
# 0  2017-06-07 15:44:28 -0500  2017-12-04 18:16:46 -0600
# 1  2017-04-27 17:27:40 -0500  2020-03-06 17:08:33 -0600
# 2  2017-08-11 15:08:48 -0500  2020-03-06 17:10:56 -0600
# 3  2018-04-30 10:15:07 -0500  2019-09-04 18:38:30 -0500
# 4  2017-12-05 14:38:43 -0600  2018-03-05 14:20:01 -0600
#
#    number of associated experiments_sites  number of associated sites  \
# 0                                       1                           1
# 1                                       0                           0
# 2                                    1027                        1027
# 3                                    2592                        2592
# 4                                       1                           1
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/experi...
# 1  https://terraref.ncsa.illinois.edu/bety/experi...
# 2  https://terraref.ncsa.illinois.edu/bety/experi...
# 3  https://terraref.ncsa.illinois.edu/bety/experi...
# 4  https://terraref.ncsa.illinois.edu/bety/experi...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/experi...
# 1  https://terraref.ncsa.illinois.edu/bety/experi...
# 2  https://terraref.ncsa.illinois.edu/bety/experi...
# 3  https://terraref.ncsa.illinois.edu/bety/experi...
# 4  https://terraref.ncsa.illinois.edu/bety/experi...

# %%
# look at the descriptions to find Season 4 and 6, for example
experiment_df[['start_date','name','description']]
# Out:
#     start_date                                               name  \
# 0   2014-05-27          Danforth Sorghum Pilot: Drought Tolerance
# 1   2016-03-15              KSU 2016-1: Biomass Association Panel
# 2   2016-06-07              KSU 2016-2: Ashland Bottoms BAP & RIL
# 3   2017-11-20                         MAC Season 5: Winter Wheat
# 4   2016-05-16  Danforth BAP Drought LT1b: Drought Experiment ...
# 5   2016-05-05  Danforth BAP Drought LT1a:  Drought Experiment...
# 6   2017-04-13     MAC Season 4: All BAP With Late Season Drought
# 7   2016-04-20                   MAC Season 1: All BAP Accessions
# 8   2018-08-23                               MAC Season 7: Border
# 9   2016-07-27                  MAC Season 2: Stay-green RILs F10
# 10  2018-08-23                  MAC Season 7: Stay-green RILs F10
# 11  2018-08-23         MAC Season 7: Sorghum Mutants, F2 families
# 12  2018-08-23     MAC Season 7: Pioneer Hybrid Uniformity Blocks
# 13  2017-04-13                         MAC Season 4: Border Plots
# 14  2016-04-20                              MAC Season 1: Uniform
# 15  2016-04-20                                 MAC Season 1: Row#
# 16  2016-04-20                                 MAC Season 1: RILs
# 17  2016-04-20                              MAC Season 1: nighthv
# 18  2016-04-20                              MAC Season 1: Density
# 19  2016-04-20                              MAC Season 1: Biomass
# 20  2016-04-20                                  MAC Season 1: BAP
# 21  2019-05-01                   MAC Season 9: South Field Border
# 22  2019-04-29                   MAC Season 9: North Field Border
# 23  2019-04-29                                  MAC Season 9: SAP
# 24  2018-04-20                          MAC Season 6: Sorghum BAP
# 25  2016-12-15                   MAC Season 3: Durum Wheat Border
# 26  2016-12-15        MAC Season 3: Durum Wheat Uniformity Trials
# 27  2016-12-15          MAC Season 3: Durum Wheat Diversity Panel
# 28  2019-05-01                    MAC Season 9: GRASSL x RIO RILs
#
#                                           description
# 0   # Materials\r\n\r\nProMix BRK20 + 14-14-14 Osm...
# 1   Bioenergy association panel (BAP) study at KSU...
# 2   Germplasm used for the project\r\n1) Bioenergy...
# 3   Durum wheat diversity panel (UNIBO panel) plan...
# 4   Sorghum Bioenergy Association Panel drought ex...
# 5   Sorghum Bioenergy Association Panel drought ex...
# 6   Biomass Association Panel (BAP), 350 accession...
# 7   Lateral and end borders planted in 2-row plots...
# 8   Lateral and end borders planted in 2-row plots...
# 9   Bi-parental grain sorghum population provided ...
# 10  Bi-parental grain sorghum population provided ...
# 11  Collaborative experiment with researchers from...
# 12  Blocks of contiguous plots planted to either P...
# 13  Lateral and end borders planted in 2-row plots...
# 14  Uniform blocks of 2 lines (forage and photoper...
# 15  3 lines (forage, sweet, PS) planted in 6-row p...
# 16  60 RILs from two populations provided by W Roo...
# 17  2 photoperiod sensitive lines planted in 3 rep...
# 18  3 sorghum lines (photoperiod sensitive, forage...
# 19  3 select sorghum lines planted in 3 replicates...
# 20  30 select accessions of the Biomass Associatio...
# 21  Lateral and end borders planted in 2-row plots...
# 22  Lateral and end borders planted in 2-row plots...
# 23
# 24  Biomass Association Panel (BAP), 336 accession...
# 25  Lateral and end borders planted in 2-row plots...
# 26  Durum wheat lines planted in uniform sections ...
# 27  The main experiment in the field trial compris...
# 28  Two replicates of 166 Recombinant Inbred Lines...

# %%
# isolate a particular season by comparing with substrings of the season name
experiment_df.loc[(experiment_df['name'] > 'MAC Season 6') & (experiment_df['name'] < 'MAC Season 7') ]
# Out:
#             id                       name  start_date    end_date  \
# 24  6000000034  MAC Season 6: Sorghum BAP  2018-04-20  2018-08-02
#
#                                           description  \
# 24  Biomass Association Panel (BAP), 336 accession...
#
#                                                design     user_id  \
# 24  BAP experiment with 336 accessions in 2 replic...  6000000004
#
#                    created_at                 updated_at  \
# 24  2018-04-30 10:18:12 -0500  2020-02-23 12:13:24 -0600
#
#     number of associated experiments_sites  number of associated sites  \
# 24                                    2592                        2592
#
#                                              view_url  \
# 24  https://terraref.ncsa.illinois.edu/bety/experi...
#
#                                              edit_url
# 24  https://terraref.ncsa.illinois.edu/bety/experi...

# %%
season4_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 4') & (experiment_df['name'] < 'MAC Season 5') ]['description'].values
season6_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 6') & (experiment_df['name'] < 'MAC Season 7') ]['description'].values
season7_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 7') & (experiment_df['name'] < 'MAC Season 8') ]['description'].values
season9_text = experiment_df.loc[(experiment_df['name'] > ' MAC Season 9:') & (experiment_df['name'] < 'MAC Season 10') ]['description'].values
print('Season 4:',season4_text)
print('------')
print('Season 6:',season6_text)
print('------')
print('Season 7:',season7_text)
print('------')
print('Season 9:',season9_text)
# Out:
# Season 4: ['Biomass Association Panel (BAP), 350 accessions in 2 replicates constrained by 3 height blocks.  \r\n\r\nThe Biomass Association Panel is described by Brenton, ZW et al.  2016.  A genomic resource for the development, improvement, and exploitation of sorghum for bioenergy.  Genetics 204: 21-33. \r\n\r\nA late season drought experiment along drip lines was established as part of the field campaigns in the latter part of season 4. This was not a pre-planned drought study, and only temporary water limited zones for the field campaign. There were two treatments. Irrigation was turned off during the first two weeks of August in the first treatment and irrigation was turned off during the second two weeks of August in the second treatment. Additional discussion can be found in https://github.com/terraref/reference-data/issues/196.'
#  'Lateral and end borders planted in 2-row plots on E/W edges and outer ranges (1-2 and 53-54) on the N/S edges to reduce edge effect. Sorghum variety SP1615 was planted on the E/W field edges, and SP1615 and Big Kahuna were planted in alternating plots on the N/S edges']
# ------
# Season 6: ['Biomass Association Panel (BAP), 336 accessions in 2 replicates (constrained by 2 height blocks) in ranges 4-51.  Ranges 3 and 52 planted primarily as uniform sections of SP1615 plus check plots for observation.  The Biomass Association Panel is described by Brenton, ZW et al. 2016. A genomic resource for the development, improvement, and exploitation of sorghum for bioenergy. Genetics 204: 21-33.']
# ------
# Season 7: ['Lateral and end borders planted in 2-row plots on E/W edges and outer ranges (1-2 and 53-54) on the N/S edges to reduce edge effect. Sorghum Pioneer hybrids P_84G62 or P_86Y89 were planted on the E/W and N/S field edges'
#  'Bi-parental grain sorghum population provided by W. Rooney (Texas A&M), comprised of two replicates of 172 RILs, 1 local check (Great Scott), and parental lines (TX7000 and SC56-14) polymorphic for grain traits and stay-green (associated with post-flowering drought tolerance). RILs are F-10 or higher generation. Lateral and end borders were Ton-A-Milk (forage hybrid). \r\n\r\nSeason 7 RIL experiment closely replicates the RIL experiment from Season 2 in 2016. The description is the same https://terraref.ncsa.illinois.edu/bety/api/v1/experiments?id=6000000008'
#  'Collaborative experiment with researchers from the USDA-ARS Plant Stress and Germplasm Development Unit in Lubbock, TX. F2 mutant families are derived from lines developed as a mutant library in BTX623, described in Xin, Zhanguo & Jiao, Yinpingn & Chopra, Ratan & Gladman, Nicholas & Burow, Gloria & Chen, Junping & Chad, Hayes & Emendack, Yves & Doreen, Ware & John, Burke. (2016). Pedigreed Mutant Library- A Unique Resource for Sorghum Improvement and Genomics. 10.2134/agronmonogr58.2014.0057.'
#  'Blocks of contiguous plots planted to either P_84G62 or P_86Y89 (Pioneer hybrids) in Ranges 3-13, for phenotyping efforts that require large areas of the same cultivar and for destructive sampling and manipulation treatments, including a small photosynthesis-inhibitor herbicide experiment to evaluate the PSII imaging system. ']
# ------
# Season 9: ['# Materials\r\n\r\nProMix BRK20 + 14-14-14 Osmocote pots; pre-filled by Hummert Sorghum seed\r\nConviron Growth House\r\nLemnaTec moving field conveyor belt system\r\nScanalyzer 3D platform\r\n\r\n# Procedures\r\n\r\n## Planting\r\n\r\nPlant directly into phenotyping pots \r\n\r\n## Chamber Conditions\r\n\r\nPre-growth (11 days) and Phenotying (11 days)\r\n14 hour photoperiod\r\n32 C day / 22 C night temperature\r\n60% relative humidity\r\n700 umol/m2/s light\r\n\r\nWatering Conditions\r\nPrior to phenotyping, plants watered daily\r\nThe first night after loading, plants watered 1× by treatment group to 100% field capacity (fc)\r\nDays 2 – 12, plants watered 2× daily by treatment group (100% or 30% FC) to target weight\r\nAutomation\r\n\r\nLeft shift lane rotation within each GH, during overnight watering jobs\r\nVIS (TV and 2 x SV), NIR (TV and 2 x SV) imaging daily\r\nRecipes\r\n\r\nField capacity = 200% GWC (200 g water/100 g soil), based upon extensive GWC testing done by Skyler Mitchell\r\nTarget weight (fc) = [(water weight at % fc) + [(average weight of carrier/saucer) + (dry soil weight) + (pot weight)]\r\nWater weight at 100% fc = dry soil weight * (%GWC/100)\r\nWater weight at 30% fc = water weight at 100% fc * 0.30'
#  'Bioenergy association panel (BAP) study at KSU Summer 2016'
#  'Germplasm used for the project\r\n1) Bioenergy association panel (BAP)\r\n       ----photo period sensitive\r\n       ----Tall to very tall\r\n       ----365 lines\r\n       ----from Clemson SC\r\n2)   Biomass Recombinant Inbred Lines (RILs)\r\n       ----R10766 X R08331\r\n       ----Photoperiod insensitive \r\n       ----semi-dwarf to mod-tall\r\n       ----about 200 lines (two families)\r\n       ----From Texas A&M\r\n\r\n'
#  'Sorghum Bioenergy Association Panel drought experiment LT1b (TM016_F_052716).'
#  'Sorghum Bioenergy Association Panel drought experiment LT1a (TM015_F_051616).']

# %%
season4_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 4') & (experiment_df['name'] < 'MAC Season 5') ]['design'].values
season6_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 6') & (experiment_df['name'] < 'MAC Season 7') ]['design'].values
season7_text = experiment_df.loc[(experiment_df['name'] > 'MAC Season 7') & (experiment_df['name'] < 'MAC Season 8') ]['design'].values
season9_text = experiment_df.loc[(experiment_df['name'] > ' MAC Season 9') & (experiment_df['name'] < 'MAC Season 10') ]['design'].values
print('Season 4:',season4_text)
print('------')
print('Season 6:',season6_text)
print('------')
print('Season 7:',season7_text)
print('------')
print('Season 9:',season9_text)
# Out:
# Season 4: ['BAP experiment with 350 accessions in 2 replicate two-row plots. Plots were 152.4 cm wide (2-rows, row width of 76.2 cm) and 3.385 meters long with 0.6 meter alley-way (total 3.985 meters long for each plot).\r\n\t\r\nExperiment arranged in two replicates (blocks) as a row-column design with a further constraint that lines (accessions) are blocked by height class. This blocking is applied across ranges. Two ranges per replicate are assigned to short stature plants, and five ranges per replicate are assigned to medium stature plants. In specifying a model for analysis, lines (accessions) are nested within height/stature classes.  See also the following reference for description of row-column designs:  Piepho, HP et al. 2015.  Beyond Latin Squares: A brief tour of row-column designs.  Agronomy Journal 107: 2263-2270.\r\n\t\r\nRanges blocked by height of BAP accessions: \r\n* Short: Ranges 11, 20, 46, 50.\r\n* Medium: Ranges 10, 12, 18, 24, 27, 29, 31, 33, 38, 51; \r\n* Tall: Ranges 3-9, 13-17,19, 21-23, 25, 26, 28, 30, 32, 35-37, 39-45, 47-49, 52\r\n\r\nDrought Treatments:\r\n* no irrigation Aug 1-14 in Cols 5, 6, 7, 8, 12, 13, 14, 15 and 16\r\n* no irrigation Aug 15-30 in Cols 1, 2, 3, 4, 9, 10, and 11\r\n'
#  '']
# ------
# Season 6: ['BAP experiment with 336 accessions in 2 replicate two-row plots in ranges 4-51. Ranges 3 and 52 included uniformity and check lines. Plots were 152.4 cm wide (2-rows, row width of 76.2 cm) and 3.385 meters long with 0.6 meter alley-way (total 3.985 meters long for each plot).\r\n\t\r\nExperiment was arranged in two replicates (blocks) as a row-column design with a further constraint that lines (accessions) are blocked by height class. This blocking is applied across ranges. In specifying a model for analysis, lines (accessions) are nested within height/stature classes.  See also the following reference for description of row-column designs:  Piepho, HP et al. 2015.  Beyond Latin Squares: A brief tour of row-column designs.  Agronomy Journal 107: 2263-2270.']
# ------
# Season 7: [''
#  'Resolvable row-column design, 3 replicates of each accession, each replicate includes checks BTX623, P_84G62, and P_86Y89.'
#  'Ranges 14-16 planted as 2-row plots of either F2 mutant families, the BTX623 wildtype, or filler plots of P_84G62.  F2 mutants were replicated within these ranges in a fully randomized experimental design.'
#  'Blocks of contiguous plots planted to either P_84G62 or P_86Y89 (Pioneer hybrids) in Ranges 3-13 (no experimental design). This can be used to evaluate the variability among plots within a given genotype.']
# ------
# Season 9: [''
#  'Field location Ashland Bottoms\r\nRandomized Block Design with augmentation\r\n   augmentation means each range has a plot w/ each check \r\n   Two blocks, one replicate plot per genotype per block\r\n   each plot consists of 4 rows\r\n\r\nBAP: 365 photoperiod sensitive lines from Steve Kresovich Clemson SC\r\nHybrid Cultivars used as checks: Ceres Blade and Richardson Pacesetter\r\nGrain Sorghum also planted to fill out empty plots'
#  'Randomized Block Design with augmentation, 2 experimental replicate 4 row plots per cultivar.\r\nProtect Fill (Border rows): four rows each side of ranges, one range each side of row, and between of two experimental blocks, two hybrid cultivars were used as fill: Ceres Blade and Richardson Pacesetter. Oats planted June 30 2016 were used as fill around experiment.'
#  'Planting was done on 2016-05-16. Germination and seedling development was done in growth chambers until 2016-05-27. Plants were phenotyped on the Danforth Center Bellwether Phenotyping Facility from 2016-05-27 to 2016-06-07. The photoperiod used was 700 umol/m^2/s light intensity for 14/10 hours light/dark at 32C/22C light/dark and 60% relative humidity. Three replicates of 190 BAP lines were grown in a randomized complete block design. Watering regimes were 30% field capacity and 100% field capacity. Drought conditions were imposed 10 days after planting.'
#  'Planting was done on 2016-05-05. Germination and seedling development was done in growth chambers until 2016-05-16. Plants were phenotyped on the Danforth Center Bellwether Phenotyping Facility from 2016-05-16 to 2016-05-27. The photoperiod used was 700 umol/m^2/s light intensity for 14/10 hours light/dark at 32C/22C light/dark and 60% relative humidity. Three replicates of 190 BAP lines were grown in a randomized complete block design. Watering regimes were 30% field capacity and 100% field capacity. Drought conditions were imposed 10 days after planting.']

# %% [markdown]
# #### Now look at the treatments applied during the relevant seasons
#
# This API lists the "control events" applied during the different seasons.  This includes the planting and harvesting dates and any special events (such as drought simulation by removing water during Season 4).  The events are listed by date and contain a management-type

# %%
manages = requests.get('https://terraref.org/bety/api/v1/managements?associations_mode=full_info')

# %%
manages.json()['data'][0]
# Out:
# {'management': {'id': 6000000001,
#   'citation_id': 6000000001,
#   'date': '2016-04-19',
#   'dateloc': '5.0',
#   'mgmttype': 'planting (plants / m2)',
#   'level': None,
#   'units': '',
#   'notes': '',
#   'created_at': '2016-08-15 12:19:57 -0500',
#   'updated_at': '2016-08-15 12:19:57 -0500',
#   'user_id': None,
#   'citation': {'id': 6000000001,
#    'author': 'Newcomb, Maria',
#    'year': 2016,
#    'title': 'Field measurements from Maricopa Agricultural Center',
#    'journal': '',
#    'vol': None,
#    'pg': '',
#    'url': '',
#    'pdf': '',
#    'created_at': '2016-06-16 16:27:59 -0500',
#    'updated_at': '2016-06-16 16:27:59 -0500',
#    'doi': '',
#    'user_id': 6000000004},
#   'treatments': [{'treatment': {'id': 6000000014,
#      'name': 'Control',
#      'definition': '',
#      'created_at': '2016-08-08 15:55:24 -0500',
#      'updated_at': '2017-03-08 21:45:18 -0600',
#      'control': True,
#      'user_id': 6000000004}}],
#   'view_url': 'https://terraref.ncsa.illinois.edu/bety/managements/6000000001',
#   'edit_url': 'https://terraref.ncsa.illinois.edu/bety/managements/6000000001/edit'}}

# %%
# build a dataframe of the experiments and their descriptive attributes. 
management_list = []
for event in manages.json()['data']:
    #print(exp)
    management_list.append(event['management'])
management_df = pd.DataFrame(management_list)
print(management_df.shape[0],' events reported')
management_df.head()
# Out:
# 113  events reported
#            id  citation_id        date dateloc                mgmttype  \
# 0  6000000001   6000000001  2016-04-19     5.0  planting (plants / m2)
# 1  6000000004   6000000001  2016-04-12     5.0                 Tillage
# 2  6000000005   6000000001  2016-04-14     5.0         Fertilization_N
# 3  6000000006   6000000001  2016-04-15     5.0                    Misc
# 4  6000000007   6000000001  2016-04-20     5.0                Planting
#
#     level      units                                              notes  \
# 0     NaN
# 1     NaN       None             Pre-plant tillage, ripping and disking
# 2  243.00    kg ha-1          Pre-plant urea fertilization at 243 kg/ha
# 3     NaN       None                                   Pre-plant S-Tine
# 4   20.67  seeds m-2  Field planted with Kincaid (on loan) at 2.5" s...
#
#                   created_at                 updated_at  user_id  \
# 0  2016-08-15 12:19:57 -0500  2016-08-15 12:19:57 -0500      NaN
# 1  2016-11-11 16:29:32 -0600  2016-11-11 16:29:32 -0600      NaN
# 2  2016-11-11 16:29:32 -0600  2016-11-11 16:29:32 -0600      NaN
# 3  2016-11-11 16:29:32 -0600  2016-11-11 16:29:32 -0600      NaN
# 4  2016-11-11 16:29:32 -0600  2016-11-11 16:29:32 -0600      NaN
#
#                                             citation  \
# 0  {'id': 6000000001, 'author': 'Newcomb, Maria',...
# 1  {'id': 6000000001, 'author': 'Newcomb, Maria',...
# 2  {'id': 6000000001, 'author': 'Newcomb, Maria',...
# 3  {'id': 6000000001, 'author': 'Newcomb, Maria',...
# 4  {'id': 6000000001, 'author': 'Newcomb, Maria',...
#
#                                           treatments  \
# 0  [{'treatment': {'id': 6000000014, 'name': 'Con...
# 1  [{'treatment': {'id': 6000000014, 'name': 'Con...
# 2  [{'treatment': {'id': 6000000014, 'name': 'Con...
# 3  [{'treatment': {'id': 6000000014, 'name': 'Con...
# 4  [{'treatment': {'id': 6000000014, 'name': 'Con...
#
#                                             view_url  \
# 0  https://terraref.ncsa.illinois.edu/bety/manage...
# 1  https://terraref.ncsa.illinois.edu/bety/manage...
# 2  https://terraref.ncsa.illinois.edu/bety/manage...
# 3  https://terraref.ncsa.illinois.edu/bety/manage...
# 4  https://terraref.ncsa.illinois.edu/bety/manage...
#
#                                             edit_url
# 0  https://terraref.ncsa.illinois.edu/bety/manage...
# 1  https://terraref.ncsa.illinois.edu/bety/manage...
# 2  https://terraref.ncsa.illinois.edu/bety/manage...
# 3  https://terraref.ncsa.illinois.edu/bety/manage...
# 4  https://terraref.ncsa.illinois.edu/bety/manage...

# %%
# are there multiple treatments per management event? Sometimes there are.  These will need to be explicitly
# parsed to see all events.
count = 0
print('each event has a Control treatment, but we do not list these....')
for event in management_list:
    print('-----')
    numTreatments = len(event['treatments'])
    print(numTreatments, 'treatments in event',event['mgmttype'])
    for tcount,treat in enumerate(event['treatments']):
        #print(treat)
        if treat['treatment']['name'] != 'Control':
            print('treatment ',tcount,':',treat['treatment'])
    #print('last treatment:',event['treatments'][-1])
    count += 1
    if count > 5:
        break
# Out:
# each event has a Control treatment, but we do not list these....
# -----
# 1 treatments in event planting (plants / m2)
# -----
# 4 treatments in event Tillage
# treatment  1 : {'id': 6000000016, 'name': 'medium density', 'definition': '46 plants per plot: 23 plants in each of two 3.5 m rows', 'created_at': '2016-08-08 16:17:52 -0500', 'updated_at': '2016-08-08 16:17:52 -0500', 'control': False, 'user_id': 6000000004}
# treatment  2 : {'id': 6000000015, 'name': 'high density', 'definition': '112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing', 'created_at': '2016-08-08 16:17:04 -0500', 'updated_at': '2016-08-08 17:06:00 -0500', 'control': False, 'user_id': 6000000004}
# treatment  3 : {'id': 6000000017, 'name': 'low density', 'definition': '24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing', 'created_at': '2016-08-08 16:18:45 -0500', 'updated_at': '2016-08-08 17:06:11 -0500', 'control': False, 'user_id': 6000000004}
# -----
# 4 treatments in event Fertilization_N
# treatment  1 : {'id': 6000000016, 'name': 'medium density', 'definition': '46 plants per plot: 23 plants in each of two 3.5 m rows', 'created_at': '2016-08-08 16:17:52 -0500', 'updated_at': '2016-08-08 16:17:52 -0500', 'control': False, 'user_id': 6000000004}
# treatment  2 : {'id': 6000000015, 'name': 'high density', 'definition': '112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing', 'created_at': '2016-08-08 16:17:04 -0500', 'updated_at': '2016-08-08 17:06:00 -0500', 'control': False, 'user_id': 6000000004}
# treatment  3 : {'id': 6000000017, 'name': 'low density', 'definition': '24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing', 'created_at': '2016-08-08 16:18:45 -0500', 'updated_at': '2016-08-08 17:06:11 -0500', 'control': False, 'user_id': 6000000004}
# -----
# 4 treatments in event Misc
# treatment  1 : {'id': 6000000016, 'name': 'medium density', 'definition': '46 plants per plot: 23 plants in each of two 3.5 m rows', 'created_at': '2016-08-08 16:17:52 -0500', 'updated_at': '2016-08-08 16:17:52 -0500', 'control': False, 'user_id': 6000000004}
# treatment  2 : {'id': 6000000015, 'name': 'high density', 'definition': '112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing', 'created_at': '2016-08-08 16:17:04 -0500', 'updated_at': '2016-08-08 17:06:00 -0500', 'control': False, 'user_id': 6000000004}
# treatment  3 : {'id': 6000000017, 'name': 'low density', 'definition': '24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing', 'created_at': '2016-08-08 16:18:45 -0500', 'updated_at': '2016-08-08 17:06:11 -0500', 'control': False, 'user_id': 6000000004}
# -----
# 1 treatments in event Planting
# -----
# 4 treatments in event Herbicide
# treatment  1 : {'id': 6000000016, 'name': 'medium density', 'definition': '46 plants per plot: 23 plants in each of two 3.5 m rows', 'created_at': '2016-08-08 16:17:52 -0500', 'updated_at': '2016-08-08 16:17:52 -0500', 'control': False, 'user_id': 6000000004}
# treatment  2 : {'id': 6000000015, 'name': 'high density', 'definition': '112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing', 'created_at': '2016-08-08 16:17:04 -0500', 'updated_at': '2016-08-08 17:06:00 -0500', 'control': False, 'user_id': 6000000004}
# treatment  3 : {'id': 6000000017, 'name': 'low density', 'definition': '24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing', 'created_at': '2016-08-08 16:18:45 -0500', 'updated_at': '2016-08-08 17:06:11 -0500', 'control': False, 'user_id': 6000000004}

# %% [markdown]
# Each treatment indicates something particular about the event.  Here we loop through a few treatments to see what type of descriptive information is included in them.  For a fine detailed understanding of how management policies changed during the seasons, these events probably need to be parsed and interpretted if they should be considered by a model or not.

# %%
# are there multiple treatments per management event? Sometimes there are.  These will need to be explicitly
# parsed to see all events.
count = 0
print('each event has a Control treatment, but we do not list these....')
for event in management_list:
    print('-----')
    numTreatments = len(event['treatments'])
    print(numTreatments, 'treatments in event',event['mgmttype'])
    for tcount,treat in enumerate(event['treatments']):
        #print(treat)
        if treat['treatment']['name'] != 'Control':
            print('treatment ',tcount,':',treat['treatment']['definition'])
    #print('last treatment:',event['treatments'][-1])
    count += 1
    if count > 5:
        break
# Out:
# each event has a Control treatment, but we do not list these....
# -----
# 1 treatments in event planting (plants / m2)
# -----
# 4 treatments in event Tillage
# treatment  1 : 46 plants per plot: 23 plants in each of two 3.5 m rows
# treatment  2 : 112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing
# treatment  3 : 24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing
# -----
# 4 treatments in event Fertilization_N
# treatment  1 : 46 plants per plot: 23 plants in each of two 3.5 m rows
# treatment  2 : 112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing
# treatment  3 : 24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing
# -----
# 4 treatments in event Misc
# treatment  1 : 46 plants per plot: 23 plants in each of two 3.5 m rows
# treatment  2 : 112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing
# treatment  3 : 24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing
# -----
# 1 treatments in event Planting
# -----
# 4 treatments in event Herbicide
# treatment  1 : 46 plants per plot: 23 plants in each of two 3.5 m rows
# treatment  2 : 112 plants per plot: 56 plants in each of two 3.5 m rows; 6.24 cm spacing
# treatment  3 : 24 plants per plot: 12 plants in each of two 3.5 m rows, ~29 cm spacing
